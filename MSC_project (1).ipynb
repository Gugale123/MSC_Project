# %% [markdown]
# ##importing a libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set('talk', palette='colorblind')

# %% [markdown]
# ##importing datasets

# %%
Data1=pd.read_csv('C:/Users/hp/Downloads/train.csv')
Data2=pd.read_csv('C:/Users/hp/Downloads/test.csv')

# %%
Data1.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
Data1.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
Data1.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
sns.countplot(data=Data1,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=Data1,x='Response')
# Out:
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %%
sns.countplot(data=Data1,x='Vehicle_Age')
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %%
sns.countplot(data=Data1,x='Vehicle_Damage')
# Out:
# <AxesSubplot:xlabel='Vehicle_Damage', ylabel='count'>

# %% [markdown]
# Encoding catagorical variable

# %% [markdown]
# ##Encoding catagorical variable "Gender"

# %%
Data1.loc[Data1['Gender']=='Male','Gender']=1
Data1.loc[Data1['Gender']=='Female','Gender']=0
Data2.loc[Data2['Gender']=='Male','Gender']=1
Data2.loc[Data2['Gender']=='Female','Gender']=0

# %%
Data1
# Out:
#             id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1      1   44                1         28.0                   0
# 1            2      1   76                1          3.0                   0
# 2            3      1   47                1         28.0                   0
# 3            4      1   21                1         11.0                   1
# 4            5      0   29                1         41.0                   1
# ...        ...    ...  ...              ...          ...                 ...
# 381104  381105      1   74                1         26.0                   1
# 381105  381106      1   30                1         37.0                   1
# 381106  381107      1   21                1         30.0                   1
# 381107  381108      0   68                1         14.0                   0
# 381108  381109      1   46                1         29.0                   0
#
# ...

# %% [markdown]
# ##Encoding catagorical variable "Vehical age"

# %%
Data1.loc[Data1['Vehicle_Age']=='< 1 Year','Vehicle_Age']=0
Data1.loc[Data1['Vehicle_Age']=='1-2 Year','Vehicle_Age']=1
Data1.loc[Data1['Vehicle_Age']=='> 2 Years','Vehicle_Age']=2
Data2.loc[Data2['Vehicle_Age']=='< 1 Year','Vehicle_Age']=0
Data2.loc[Data2['Vehicle_Age']=='1-2 Year','Vehicle_Age']=1
Data2.loc[Data2['Vehicle_Age']=='> 2 Years','Vehicle_Age']=2

# %%
Data1
# Out:
#             id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1      1   44                1         28.0                   0
# 1            2      1   76                1          3.0                   0
# 2            3      1   47                1         28.0                   0
# 3            4      1   21                1         11.0                   1
# 4            5      0   29                1         41.0                   1
# ...        ...    ...  ...              ...          ...                 ...
# 381104  381105      1   74                1         26.0                   1
# 381105  381106      1   30                1         37.0                   1
# 381106  381107      1   21                1         30.0                   1
# 381107  381108      0   68                1         14.0                   0
# 381108  381109      1   46                1         29.0                   0
#
# ...

# %% [markdown]
# ##Encoding catagorical variable "Vehical_damage"

# %%
Data1.loc[Data1['Vehicle_Damage']=='Yes','Vehicle_Damage']=1
Data1.loc[Data1['Vehicle_Damage']=='No','Vehicle_Damage']=0
Data2.loc[Data2['Vehicle_Damage']=='Yes','Vehicle_Damage']=1
Data2.loc[Data2['Vehicle_Damage']=='No','Vehicle_Damage']=0

# %%
Data1
# Out:
#             id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1      1   44                1         28.0                   0
# 1            2      1   76                1          3.0                   0
# 2            3      1   47                1         28.0                   0
# 3            4      1   21                1         11.0                   1
# 4            5      0   29                1         41.0                   1
# ...        ...    ...  ...              ...          ...                 ...
# 381104  381105      1   74                1         26.0                   1
# 381105  381106      1   30                1         37.0                   1
# 381106  381107      1   21                1         30.0                   1
# 381107  381108      0   68                1         14.0                   0
# 381108  381109      1   46                1         29.0                   0
#
# ...

# %% [markdown]
# ##Changing a data type of a catagoracal variable (Gender,Vehicle_Age,Vehicle_Damage) from object to numeric

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
Data1['Gender']=pd.to_numeric(Data1['Gender'])
Data1['Vehicle_Age']=pd.to_numeric(Data1['Vehicle_Age'])
Data1['Vehicle_Damage']=pd.to_numeric(Data1['Vehicle_Damage'])
Data2['Gender']=pd.to_numeric(Data2['Gender'])
Data2['Vehicle_Age']=pd.to_numeric(Data2['Vehicle_Age'])
Data2['Vehicle_Damage']=pd.to_numeric(Data2['Vehicle_Damage'])

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  int64
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  int64
#  7   Vehicle_Damage        381109 non-null  int64
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 34.9 MB

# %%
Data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  int64
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  float64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  int64
#  7   Vehicle_Damage        127037 non-null  int64
#  8   Annual_Premium        127037 non-null  float64
#  9   Policy_Sales_Channel  127037 non-null  float64
#  10  Vintage               127037 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 10.7 MB

# %% [markdown]
# # 2]EDA(Explonatary Data analysis)

# %% [markdown]
# ## 1)Id

# %% [markdown]
# id does not give any valid information about response variable 'Responces' so we are dropping I'd variable from our dataset

# %%
Data1=Data1.drop('id',axis=1)
Data2=Data2.drop('id',axis=1)

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                381109 non-null  int64
#  1   Age                   381109 non-null  int64
#  2   Driving_License       381109 non-null  int64
#  3   Region_Code           381109 non-null  float64
#  4   Previously_Insured    381109 non-null  int64
#  5   Vehicle_Age           381109 non-null  int64
#  6   Vehicle_Damage        381109 non-null  int64
#  7   Annual_Premium        381109 non-null  float64
#  8   Policy_Sales_Channel  381109 non-null  float64
#  9   Vintage               381109 non-null  int64
#  10  Response              381109 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 32.0 MB

# %% [markdown]
# ##2)Gender

# %%
sns.countplot(data=Data1,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=Data1,x='Gender',hue='Response')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ##3)age

# %% [markdown]
# ###distribution of age variable

# %%
sns.displot(data=Data1, x="Age")

# %%
sns.catplot(data=Data1,x='Response',col='Age',kind='count',col_wrap=5)

# %%
Data1.drop(Data1[Data1['Age']==20].index, inplace=True)
Data1.drop(Data1[Data1['Age']==85].index, inplace=True)
Data1.drop(Data1[Data1['Age']==81].index, inplace=True)
Data1.drop(Data1[Data1['Age']==82].index, inplace=True)
Data1.drop(Data1[Data1['Age']==83].index, inplace=True)
Data1.drop(Data1[Data1['Age']==84].index, inplace=True)

# %%
 
Data2.drop(Data2[Data2['Age']==20].index, inplace=True)
Data2.drop(Data2[Data2['Age']==85].index, inplace=True)
Data2.drop(Data2[Data2['Age']==81].index, inplace=True)
Data2.drop(Data2[Data2['Age']==82].index, inplace=True)
Data2.drop(Data2[Data2['Age']==83].index, inplace=True)
Data2.drop(Data2[Data2['Age']==84].index, inplace=True)

# %%
sns.catplot(data=Data1,x='Response',col='Age',kind='count',col_wrap=5)

# %% [markdown]
# ## 4) Driving licence

# %%
sns.countplot(data=Data1,x='Driving_License')
# Out:
# <AxesSubplot:xlabel='Driving_License', ylabel='count'>

# %%
sns.countplot(data=Data1,x='Driving_License',hue='Response')
# Out:
# <AxesSubplot:xlabel='Driving_License', ylabel='count'>

# %%
Data=Data1
data=Data2

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374748 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                374748 non-null  int64
#  1   Age                   374748 non-null  int64
#  2   Driving_License       374748 non-null  int64
#  3   Region_Code           374748 non-null  float64
#  4   Previously_Insured    374748 non-null  int64
#  5   Vehicle_Age           374748 non-null  int64
#  6   Vehicle_Damage        374748 non-null  int64
#  7   Annual_Premium        374748 non-null  float64
#  8   Policy_Sales_Channel  374748 non-null  float64
#  9   Vintage               374748 non-null  int64
#  10  Response              374748 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 44.3 MB

# %%
Data=Data.drop('Driving_License',axis=1)
data=data.drop('Driving_License',axis=1)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374748 entries, 0 to 381108
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                374748 non-null  int64
#  1   Age                   374748 non-null  int64
#  2   Region_Code           374748 non-null  float64
#  3   Previously_Insured    374748 non-null  int64
#  4   Vehicle_Age           374748 non-null  int64
#  5   Vehicle_Damage        374748 non-null  int64
#  6   Annual_Premium        374748 non-null  float64
#  7   Policy_Sales_Channel  374748 non-null  float64
#  8   Vintage               374748 non-null  int64
#  9   Response              374748 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 41.5 MB

# %% [markdown]
# ##5)Region_Code

# %%
sns.displot(data=Data, x="Region_Code")

# %%
sns.catplot(data=Data,x='Response',col='Region_Code',kind='count',col_wrap=5)

# %%
for i in range(0,52):
    if len(Data[Data['Region_Code']==i].index)<=5000:
       Data.drop(Data[Data['Region_Code']==i].index, inplace=True)
Data.drop(Data[Data['Region_Code']==15].index, inplace=True)
Data.drop(Data[Data['Region_Code']==36].index, inplace=True)
Data.drop(Data[Data['Region_Code']==47].index, inplace=True)
Data.drop(Data[Data['Region_Code']==50].index, inplace=True)
Data.drop(Data[Data['Region_Code']==47].index, inplace=True)
Data.drop(Data[Data['Region_Code']==52].index, inplace=True)
Data.drop(Data[Data['Region_Code']==45].index, inplace=True)
Data.drop(Data[Data['Region_Code']==37].index, inplace=True)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243225 entries, 0 to 381108
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                243225 non-null  int64
#  1   Age                   243225 non-null  int64
#  2   Region_Code           243225 non-null  float64
#  3   Previously_Insured    243225 non-null  int64
#  4   Vehicle_Age           243225 non-null  int64
#  5   Vehicle_Damage        243225 non-null  int64
#  6   Annual_Premium        243225 non-null  float64
#  7   Policy_Sales_Channel  243225 non-null  float64
#  8   Vintage               243225 non-null  int64
#  9   Response              243225 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 20.4 MB

# %%
for i in range(0,52):
    if len(data[data['Region_Code']==i].index)<=2000:
       data.drop(data[data['Region_Code']==i].index, inplace=True)
data.drop(data[data['Region_Code']==15].index, inplace=True)
data.drop(data[data['Region_Code']==36].index, inplace=True)
data.drop(data[data['Region_Code']==47].index, inplace=True)
data.drop(data[data['Region_Code']==50].index, inplace=True)
data.drop(data[data['Region_Code']==47].index, inplace=True)
data.drop(data[data['Region_Code']==52].index, inplace=True)
data.drop(data[data['Region_Code']==45].index, inplace=True)
data.drop(data[data['Region_Code']==37].index, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79502 entries, 0 to 127036
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                79502 non-null  int64
#  1   Age                   79502 non-null  int64
#  2   Region_Code           79502 non-null  float64
#  3   Previously_Insured    79502 non-null  int64
#  4   Vehicle_Age           79502 non-null  int64
#  5   Vehicle_Damage        79502 non-null  int64
#  6   Annual_Premium        79502 non-null  float64
#  7   Policy_Sales_Channel  79502 non-null  float64
#  8   Vintage               79502 non-null  int64
# dtypes: float64(3), int64(6)
# memory usage: 8.6 MB

# %%
sns.catplot(data=Data,x='Response',col='Region_Code',kind='count',col_wrap=5)

# %%
Data.loc[Data['Region_Code']==18,'Region_Code']=0
Data.loc[Data['Region_Code']==35,'Region_Code']=1
Data.loc[Data['Region_Code']==6,'Region_Code']=2
Data.loc[Data['Region_Code']==33,'Region_Code']=3
Data.loc[Data['Region_Code']==11,'Region_Code']=4
Data.loc[Data['Region_Code']==3,'Region_Code']=7
Data.loc[Data['Region_Code']==29,'Region_Code']=5
Data.loc[Data['Region_Code']==30,'Region_Code']=6
Data.loc[Data['Region_Code']==41,'Region_Code']=8
Data.loc[Data['Region_Code']==46,'Region_Code']=9
Data.loc[Data['Region_Code']==8,'Region_Code']=10
Data.loc[Data['Region_Code']==28,'Region_Code']=11

# %%
 
data.loc[data['Region_Code']==35,'Region_Code']=1
data.loc[data['Region_Code']==6,'Region_Code']=2
data.loc[data['Region_Code']==33,'Region_Code']=3
data.loc[data['Region_Code']==11,'Region_Code']=4
data.loc[data['Region_Code']==3,'Region_Code']=7
data.loc[data['Region_Code']==29,'Region_Code']=5
data.loc[data['Region_Code']==30,'Region_Code']=6
data.loc[data['Region_Code']==41,'Region_Code']=8
data.loc[data['Region_Code']==46,'Region_Code']=9
data.loc[data['Region_Code']==8,'Region_Code']=10
data.loc[data['Region_Code']==28,'Region_Code']=11

# %%
sns.countplot(data=Data,x='Region_Code')
# Out:
# <AxesSubplot:xlabel='Region_Code', ylabel='count'>

# %%
sns.countplot(data=data,x='Region_Code')
# Out:
# <AxesSubplot:xlabel='Region_Code', ylabel='count'>

# %% [markdown]
# ##6)Previously_Insured

# %%
sns.countplot(data=Data, x="Previously_Insured")
# Out:
# <AxesSubplot:xlabel='Previously_Insured', ylabel='count'>

# %%
sns.countplot(data=Data,x='Previously_Insured',hue='Response')
# Out:
# <AxesSubplot:xlabel='Previously_Insured', ylabel='count'>

# %% [markdown]
# ##7)Vehicle age

# %%
sns.countplot(data=Data, x="Vehicle_Age")
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %%
sns.countplot(data=Data,x='Vehicle_Age',hue='Response')
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %% [markdown]
# ##8)vehicle damage

# %%
sns.countplot(data=Data, x="Vehicle_Damage")
# Out:
# <AxesSubplot:xlabel='Vehicle_Damage', ylabel='count'>

# %%
sns.countplot(data=Data,x='Vehicle_Damage',hue='Response')
# Out:
# <AxesSubplot:xlabel='Vehicle_Damage', ylabel='count'>

# %% [markdown]
# ##9) Annual Premium

# %%
sns.kdeplot(data=Data, x="Annual_Premium")
# Out:
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Density'>

# %%
sns.kdeplot(data=Data, x="Annual_Premium",hue='Response')
# Out:
# <AxesSubplot:xlabel='Annual_Premium', ylabel='Density'>

# %%
Data.describe()
# Out:
#               Gender            Age    Region_Code  Previously_Insured  \
# count  243225.000000  243225.000000  243225.000000       243225.000000
# mean        0.550552      40.831263       8.838281            0.451528
# std         0.497439      15.458771       3.008167            0.497646
# min         0.000000      21.000000       0.000000            0.000000
# 25%         0.000000      26.000000       7.000000            0.000000
# 50%         1.000000      40.000000      10.000000            0.000000
# 75%         1.000000      51.000000      11.000000            1.000000
# max         1.000000      80.000000      11.000000            1.000000
#
#          Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# count  243225.000000   243225.000000   243225.000000         243225.000000
# mean        0.688412        0.520810    33644.685168            105.771380
# std         0.564697        0.499568    17499.893726             55.366328
# ...

# %%
Data=Data.drop("Annual_Premium",axis=1)
data=data.drop("Annual_Premium",axis=1)

# %% [markdown]
# ##10)Policy_Sales_Channel

# %%
sns.kdeplot(data=Data,x='Policy_Sales_Channel')
# Out:
# <AxesSubplot:xlabel='Policy_Sales_Channel', ylabel='Density'>

# %%
sns.catplot(data=Data,x='Response',col='Policy_Sales_Channel',kind='count',col_wrap=5)

# %%
for i in range(1,25):
    if len(Data[Data['Policy_Sales_Channel']==i].index)<=2500:
       Data.drop(Data[Data['Policy_Sales_Channel']==i].index, inplace=True)
Data.drop(Data[Data['Policy_Sales_Channel']==24].index, inplace=True)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234666 entries, 0 to 381108
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                234666 non-null  int64
#  1   Age                   234666 non-null  int64
#  2   Region_Code           234666 non-null  float64
#  3   Previously_Insured    234666 non-null  int64
#  4   Vehicle_Age           234666 non-null  int64
#  5   Vehicle_Damage        234666 non-null  int64
#  6   Policy_Sales_Channel  234666 non-null  float64
#  7   Vintage               234666 non-null  int64
#  8   Response              234666 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 27.9 MB

# %%
for i in range(26,163):
    if len(Data[Data['Policy_Sales_Channel']==i].index)<=2500:
       Data.drop(Data[Data['Policy_Sales_Channel']==i].index, inplace=True)
Data.drop(Data[Data['Policy_Sales_Channel']==160].index, inplace=True)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213605 entries, 0 to 381108
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                213605 non-null  int64
#  1   Age                   213605 non-null  int64
#  2   Region_Code           213605 non-null  float64
#  3   Previously_Insured    213605 non-null  int64
#  4   Vehicle_Age           213605 non-null  int64
#  5   Vehicle_Damage        213605 non-null  int64
#  6   Policy_Sales_Channel  213605 non-null  float64
#  7   Vintage               213605 non-null  int64
#  8   Response              213605 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 16.3 MB

# %%
for i in range(1,25):
    if len(data[data['Policy_Sales_Channel']==i].index)<=1000:
       data.drop(data[data['Policy_Sales_Channel']==i].index, inplace=True)
data.drop(data[data['Policy_Sales_Channel']==24].index, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76679 entries, 0 to 127036
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                76679 non-null  int64
#  1   Age                   76679 non-null  int64
#  2   Region_Code           76679 non-null  float64
#  3   Previously_Insured    76679 non-null  int64
#  4   Vehicle_Age           76679 non-null  int64
#  5   Vehicle_Damage        76679 non-null  int64
#  6   Policy_Sales_Channel  76679 non-null  float64
#  7   Vintage               76679 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 7.8 MB

# %%
for i in range(26,163):
    if len(data[data['Policy_Sales_Channel']==i].index)<=1000:
       data.drop(data[data['Policy_Sales_Channel']==i].index, inplace=True)
data.drop(data[data['Policy_Sales_Channel']==24].index, inplace=True)
data.info()
data.drop(data[data['Policy_Sales_Channel']==160].index, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72375 entries, 0 to 127036
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                72375 non-null  int64
#  1   Age                   72375 non-null  int64
#  2   Region_Code           72375 non-null  float64
#  3   Previously_Insured    72375 non-null  int64
#  4   Vehicle_Age           72375 non-null  int64
#  5   Vehicle_Damage        72375 non-null  int64
#  6   Policy_Sales_Channel  72375 non-null  float64
#  7   Vintage               72375 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 7.5 MB

# %%
sns.catplot(data=Data,x='Response',col='Policy_Sales_Channel',kind='count',col_wrap=5)

# %%
Data.loc[Data['Policy_Sales_Channel']==25,'Policy_Sales_Channel']=0
Data.loc[Data['Policy_Sales_Channel']==163,'Policy_Sales_Channel']=1
Data.loc[Data['Policy_Sales_Channel']==154,'Policy_Sales_Channel']=2
Data.loc[Data['Policy_Sales_Channel']==157,'Policy_Sales_Channel']=3
Data.loc[Data['Policy_Sales_Channel']==156,'Policy_Sales_Channel']=4
Data.loc[Data['Policy_Sales_Channel']==122,'Policy_Sales_Channel']=5
Data.loc[Data['Policy_Sales_Channel']==152,'Policy_Sales_Channel']=8
Data.loc[Data['Policy_Sales_Channel']==124,'Policy_Sales_Channel']=6
Data.loc[Data['Policy_Sales_Channel']==26,'Policy_Sales_Channel']=7

# %%
data.loc[data['Policy_Sales_Channel']==25,'Policy_Sales_Channel']=0
data.loc[data['Policy_Sales_Channel']==163,'Policy_Sales_Channel']=1
data.loc[data['Policy_Sales_Channel']==154,'Policy_Sales_Channel']=2
data.loc[data['Policy_Sales_Channel']==157,'Policy_Sales_Channel']=3
data.loc[data['Policy_Sales_Channel']==156,'Policy_Sales_Channel']=4
data.loc[data['Policy_Sales_Channel']==122,'Policy_Sales_Channel']=5
data.loc[data['Policy_Sales_Channel']==152,'Policy_Sales_Channel']=8
data.loc[data['Policy_Sales_Channel']==124,'Policy_Sales_Channel']=6
data.loc[data['Policy_Sales_Channel']==26,'Policy_Sales_Channel']=7

# %%
sns.countplot(data=Data,x='Policy_Sales_Channel')
# Out:
# <AxesSubplot:xlabel='Policy_Sales_Channel', ylabel='count'>

# %%
sns.countplot(data=data,x='Policy_Sales_Channel')
# Out:
# <AxesSubplot:xlabel='Policy_Sales_Channel', ylabel='count'>

# %%
sns.kdeplot(data=Data, x="Policy_Sales_Channel",hue='Response')
# Out:
# <AxesSubplot:xlabel='Policy_Sales_Channel', ylabel='Density'>

# %% [markdown]
# ##11)Vintage

# %%
sns.kdeplot(data=Data, x="Vintage")
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %%
sns.kdeplot(data=Data, x="Vintage",hue='Response')
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='Density'>

# %%
Data=Data.drop("Vintage",axis=1)
data=data.drop("Vintage",axis=1)

# %% [markdown]
# ## standardising

# %%
from sklearn.preprocessing import StandardScaler

# %%
Data[['Age']]=StandardScaler().fit_transform(Data[['Age']])
data[['Age']]=StandardScaler().fit_transform(data[['Age']])

# %%
Data
# Out:
#         Gender       Age  Region_Code  Previously_Insured  Vehicle_Age  \
# 0            1  0.223348         11.0                   0            2
# 1            1  2.323550          7.0                   0            1
# 2            1  0.420242         11.0                   0            2
# 3            1 -1.286172          4.0                   1            0
# 4            0 -0.761121         10.0                   1            0
# ...        ...       ...          ...                 ...          ...
# 381099       0  0.682767         11.0                   0            1
# 381100       0 -0.761121         11.0                   0            0
# 381101       0  1.929762         11.0                   0            2
# 381102       0 -1.023646         10.0                   1            0
# 381108       1  0.354611          5.0                   0            1
#
#         Vehicle_Damage  Policy_Sales_Channel  Response
# 0                    1                   7.0         1
# ...

# %%
data
# Out:
#         Gender       Age  Region_Code  Previously_Insured  Vehicle_Age  \
# 0            1 -1.031317          4.0                   1            0
# 2            1  0.418289         11.0                   0            1
# 4            1 -0.899535         11.0                   1            0
# 5            1 -1.228991          6.0                   1            0
# 7            1 -1.031317         10.0                   1            0
# ...        ...       ...          ...                 ...          ...
# 127031       1 -1.294882         10.0                   1            0
# 127033       0 -0.174732         11.0                   0            1
# 127034       1 -1.294882          9.0                   1            0
# 127035       1  1.999677         11.0                   1            1
# 127036       1  0.022942          5.0                   1            1
#
#         Vehicle_Damage  Policy_Sales_Channel
# 0                    0                   8.0
# ...

# %% [markdown]
# # 4]Fiting a models

# %%
D1=Data

# %%
X = D1.iloc[:, :-1].values
y = D1.iloc[:, -1].values
X1 = data.iloc[:, :].values

# %%
sns.countplot(data=D1,x='Response')
# Out:
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %% [markdown]
# ## splitting dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %%
X_train
# Out:
# array([[ 1.        ,  0.81402995, 11.        , ...,  2.        ,
#          1.        ,  7.        ],
#        [ 1.        ,  0.87966125, 11.        , ...,  1.        ,
#          1.        ,  6.        ],
#        [ 0.        , -1.02364637, 10.        , ...,  0.        ,
#          0.        ,  8.        ],
#        ...,
#        [ 1.        ,  0.81402995,  5.        , ...,  1.        ,
#          0.        ,  6.        ],
#        [ 0.        , -1.22054026,  7.        , ...,  0.        ,
#          0.        ,  8.        ],
#        [ 1.        , -0.49859599,  6.        , ...,  0.        ,
#          0.        ,  8.        ]])

# %% [markdown]
# ##1)fiting a Random forest model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1 = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 0)
classifier1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ###Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred1 = classifier1.predict(X_test)
report1=precision_recall_fscore_support(y_test,y_pred1)
cm = confusion_matrix(y_test, y_pred1)
print(cm)
print(accuracy_score(y_test, y_pred1))
a1=accuracy_score(y_test, y_pred1)
print(classification_report(y_test, y_pred1))
# Out:
# [[17728   511]
#  [ 2810   312]]
# 0.8445297504798465
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91     18239
#            1       0.38      0.10      0.16      3122
#
#     accuracy                           0.84     21361
#    macro avg       0.62      0.54      0.54     21361
# weighted avg       0.79      0.84      0.80     21361

# %%
report1
# Out:
# (array([0.86318045, 0.37910085]),
#  array([0.97198311, 0.09993594]),
#  array([0.91435645, 0.1581749 ]),
#  array([18239,  3122], dtype=int64))

# %% [markdown]
# ##2) fiting logistic Regression model

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y_train,X_train)
classifier2=logit_model.fit()
print(classifier2.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.317263
#          Iterations 11
#                           Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.240
# Dependent Variable: y                AIC:              121997.6546
# Date:               2021-04-17 18:51 BIC:              122068.8203
# No. Observations:   192244           Log-Likelihood:   -60992.
# Df Model:           6                LL-Null:          -80212.
# Df Residuals:       192237           LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     11.0000
# ---------------------------------------------------------------------
#        Coef.     Std.Err.       z        P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------
# x1    -0.0620      0.0140     -4.4226    0.0000    -0.0894    -0.0345
# ...

# %% [markdown]
# ###Confusinon Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred2 = (classifier2.predict(X_test)>0.5)
report2=precision_recall_fscore_support(y_test,y_pred2)
cm = confusion_matrix(y_test, y_pred2)
print(cm)
print(accuracy_score(y_test, y_pred2))
a2=accuracy_score(y_test, y_pred2)
print(classification_report(y_test, y_pred2))
# Out:
# [[18006   233]
#  [ 3004   118]]
# 0.8484621506483779
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92     18239
#            1       0.34      0.04      0.07      3122
#
#     accuracy                           0.85     21361
#    macro avg       0.60      0.51      0.49     21361
# weighted avg       0.78      0.85      0.79     21361

# %% [markdown]
#  ## 3)Fiting KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier3 = KNeighborsClassifier(n_neighbors = 3, metric = 'minkowski', p = 2)
classifier3.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ###Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred3 = classifier3.predict(X_test)
report3=precision_recall_fscore_support(y_test,y_pred3)
cm = confusion_matrix(y_test, y_pred3)
print(cm)
print(accuracy_score(y_test, y_pred3))
a3=accuracy_score(y_test, y_pred3)
print(classification_report(y_test, y_pred3))
# Out:
# [[16793  1446]
#  [ 2358   764]]
# 0.8219184495107907
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     18239
#            1       0.35      0.24      0.29      3122
#
#     accuracy                           0.82     21361
#    macro avg       0.61      0.58      0.59     21361
# weighted avg       0.80      0.82      0.81     21361

# %% [markdown]
# ##4) training decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
classifier4 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier4.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ###Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred4 = classifier4.predict(X_test)
report4=precision_recall_fscore_support(y_test,y_pred4)
cm = confusion_matrix(y_test, y_pred4)
print(cm)
print(accuracy_score(y_test, y_pred4))
a4=accuracy_score(y_test, y_pred4)
print(classification_report(y_test, y_pred4))
# Out:
# [[17809   430]
#  [ 2863   259]]
# 0.8458405505360236
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     18239
#            1       0.38      0.08      0.14      3122
#
#     accuracy                           0.85     21361
#    macro avg       0.62      0.53      0.53     21361
# weighted avg       0.79      0.85      0.80     21361

# %% [markdown]
#  ## 5) fiting naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier5 = GaussianNB()
classifier5.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ###Confusion Matrix

# %%
 
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred5 = classifier5.predict(X_test)
report5=precision_recall_fscore_support(y_test,y_pred5)
cm = confusion_matrix(y_test, y_pred5)
print(cm)
print(accuracy_score(y_test, y_pred5))
a5=accuracy_score(y_test, y_pred5)
print(classification_report(y_test, y_pred5))
# Out:
# [[10850  7389]
#  [   91  3031]]
# 0.6498291278498197
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     18239
#            1       0.29      0.97      0.45      3122
#
#     accuracy                           0.65     21361
#    macro avg       0.64      0.78      0.60     21361
# weighted avg       0.89      0.65      0.70     21361

# %% [markdown]
# ##6) Training Kernal SVM

# %%
from sklearn.svm import SVC
classifier6 = SVC(kernel = 'rbf', random_state = 0)
classifier6.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_recall_fscore_support
y_pred6 = classifier6.predict(X_test)
report6=precision_recall_fscore_support(y_test,y_pred6)
cm = confusion_matrix(y_test, y_pred6)
print(cm)
print(accuracy_score(y_test, y_pred6))
a6=accuracy_score(y_test, y_pred6)
print(classification_report(y_test, y_pred6))
# Out:
# [[18239     0]
#  [ 3122     0]]
# 0.8538457937362482
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     18239
#            1       0.00      0.00      0.00      3122
#
#     accuracy                           0.85     21361
#    macro avg       0.43      0.50      0.46     21361
# weighted avg       0.73      0.85      0.79     21361
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ###Result

# %%
R={'Models':['RanF','Logi','KNN','DTree','NBayes','Ksvm'],
   'Recall':[report1[1][1].round(2),report2[1][1].round(2),report3[1][1].round(2),report4[1][1].round(2),report5[1][1].round(2),report6[1][1].round(2)],
   'Precision':[report1[0][1].round(2),report2[0][1].round(2),report3[0][1].round(2),report4[0][1].round(2),report5[0][1].round(2),report6[0][1].round(2)],
   'Accuracy':[a1.round(2),a2.round(2),a3.round(2),a4.round(2),a5.round(2),a6.round(2)]}

# %%
Result=pd.DataFrame(R)

# %%
print(Result)
# Out:
#    Models  Recall  Precision  Accuracy
# 0    RanF    0.10       0.38      0.84
# 1    Logi    0.04       0.34      0.85
# 2     KNN    0.24       0.35      0.82
# 3   DTree    0.08       0.38      0.85
# 4  NBayes    0.97       0.29      0.65
# 5    Ksvm    0.00       0.00      0.85

# %% [markdown]
# # 5]Finding a result using naive Bayes classification rule

# %%
K=list(classifier5.predict(X1))

# %%
D=data.assign(Response=K)

# %%
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69649 entries, 0 to 127036
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                69649 non-null  int64
#  1   Age                   69649 non-null  float64
#  2   Region_Code           69649 non-null  float64
#  3   Previously_Insured    69649 non-null  int64
#  4   Vehicle_Age           69649 non-null  int64
#  5   Vehicle_Damage        69649 non-null  int64
#  6   Policy_Sales_Channel  69649 non-null  float64
#  7   Response              69649 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 7.3 MB

# %%
sns.countplot(data=D,x='Response')
# Out:
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %%
D.loc[D['Response']==1,'Response']='Y'
D.loc[D['Response']==0,'Response']='N'

# %%
D.to_csv("final.csv")
